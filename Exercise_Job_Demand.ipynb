# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
# creating a new variable for us jobs
df_US = df[df['job_country'] == 'United States'].copy()

# %%
# Creating a new column for months
df_US['job_posted_month'] = df_US['job_posted_date'].dt.strftime('%B')

# %%
df_US
# Out:
#              job_title_short  ... job_posted_month
# 0       Senior Data Engineer  ...             June
# 3              Data Engineer  ...             July
# 5              Data Engineer  ...         November
# 6       Senior Data Engineer  ...            March
# 9             Data Scientist  ...            April
# ...                      ...  ...              ...
# 785673        Data Scientist  ...          October
# 785685          Data Analyst  ...             July
# 785692        Data Scientist  ...            April
# 785703          Data Analyst  ...          January
# 785705          Data Analyst  ...          January
#
# [206292 rows x 18 columns]

# %%
 # df_US = df_US.drop('job_poseted_month', axis=1, inplace=True)

# %%
# counting how many job titles in each month
df_US_pivot = df_US.pivot_table(index='job_posted_month', columns='job_title_short', aggfunc='size')

# %%
df_US_pivot
# Out:
# job_title_short   Business Analyst  ...  Software Engineer
# job_posted_month                    ...
# April                          565  ...                112
# August                         903  ...                194
# December                       648  ...                212
# February                       447  ...                 90
# January                        527  ...                114
# July                           581  ...                153
# June                           446  ...                 93
# March                          438  ...                115
# May                            279  ...                 90
# November                       719  ...                194
# October                        932  ...                219
# September                      897  ...                228
#
# [12 rows x 10 columns]

# %%
df_US_pivot.reset_index(inplace=True)

# %%
df_US_pivot['montn_no'] = pd.to_datetime(df_US_pivot['job_posted_month'], format='%B').dt.month

# %%
df_US_pivot.sort_values('montn_no', inplace=True)

# %%
df_US_pivot.set_index('job_posted_month', inplace=True)

# %%
df_US_pivot
# Out:
# job_title_short   Business Analyst  Cloud Engineer  ...  Software Engineer  montn_no
# job_posted_month                                    ...
# January                        527              36  ...                114         1
# February                       447              24  ...                 90         2
# March                          438              19  ...                115         3
# April                          565              40  ...                112         4
# May                            279              20  ...                 90         5
# June                           446              32  ...                 93         6
# July                           581              39  ...                153         7
# August                         903              39  ...                194         8
# September                      897              50  ...                228         9
# ...

# %%
df_US_pivot.drop(columns='montn_no', inplace=True)

# %%
df_US_pivot
# Out:
# job_title_short   Business Analyst  ...  Software Engineer
# job_posted_month                    ...
# January                        527  ...                114
# February                       447  ...                 90
# March                          438  ...                115
# April                          565  ...                112
# May                            279  ...                 90
# June                           446  ...                 93
# July                           581  ...                153
# August                         903  ...                194
# September                      897  ...                228
# October                        932  ...                219
# November                       719  ...                194
# December                       648  ...                212
#
# [12 rows x 10 columns]

# %%
df_US_pivot.plot(kind='line')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
top_4 = df_US['job_title_short'].value_counts().head(4)
top_4 = top_4.index.to_list()
top_4
# Out:
# ['Data Analyst', 'Data Scientist', 'Data Engineer', 'Senior Data Scientist']

# %%
df_US_pivot[top_4].plot(kind='line')
plt.title('Monthly Job Postings For Top 4 Jobs In The US')
plt.xlabel('2023')
plt.ylabel('Job Count')
plt.legend()
plt.show()
