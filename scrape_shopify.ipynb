# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
url = ('https://kyliecosmetics.com/products.json')
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
df = pd.DataFrame(page.json()['products'])
df
# Out:
#                id                                          title  \
# 0   8738505949426                            Hybrid Blush Bundle
# 1   8738505326834            Hybrid Blush & Foundation Brush Duo
# 2   8738504737010                  Hybrid Blush & Lip Butter Duo
# 3   8738504311026          Hybrid Blush & Tinted Butter Balm Duo
# 4   8726121513202                                   Hybrid Blush
# 5   8740037624050                  Detox Face Mask Deluxe Sample
# 6   8736767181042              Kylie's Met Gala Look 2025 Bundle
# 7   8371480428786              Kylie's Met Gala Look 2024 Bundle
# 8   8735967150322              Kylie's Met Gala Look 2023 Bundle
# 9   7864691818738                                 High Gloss Set
# 10  8703046975730   Cosmic Kylie Jenner & 2.0 Pen Spray Gift Set
# 11  8425264414962                               Coconut Body Duo
# 12  7843563241714                             Coconut Body Scrub
# ...

# %%
clean_1 = df[['id','title','product_type','tags','images']].copy()
clean_1
# Out:
#                id                                          title product_type  \
# 0   8738505949426                            Hybrid Blush Bundle       Bundle
# 1   8738505326834            Hybrid Blush & Foundation Brush Duo       Bundle
# 2   8738504737010                  Hybrid Blush & Lip Butter Duo       Bundle
# 3   8738504311026          Hybrid Blush & Tinted Butter Balm Duo       Bundle
# 4   8726121513202                                   Hybrid Blush        Blush
# 5   8740037624050                  Detox Face Mask Deluxe Sample       Sample
# 6   8736767181042              Kylie's Met Gala Look 2025 Bundle       Bundle
# 7   8371480428786              Kylie's Met Gala Look 2024 Bundle       Bundle
# 8   8735967150322              Kylie's Met Gala Look 2023 Bundle       Bundle
# 9   7864691818738                                 High Gloss Set    Lip Gloss
# 10  8703046975730   Cosmic Kylie Jenner & 2.0 Pen Spray Gift Set          Set
# ...
