# %%
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## Sampling Data
# **Using the sample()**

# %%
df.sample(10)   # Displays a random sample of 10 values
# Out:
#              job_title_short                                job_title  \
# 468327         Data Engineer                            Data Engineer
# 204775          Data Analyst       Business Data Analyst (Healthcare)
# 125738        Data Scientist  Power Platform Developer/Data Scientist
# 233401          Data Analyst         Intern Finance and Data Analysis
# 559503      Business Analyst                       Salesforce Analyst
# 619800  Senior Data Engineer                     Senior Data Engineer
# 358908        Data Scientist                           Data Scientist
# 101356        Data Scientist                     Staff Data Scientist
# 566272        Data Scientist                           Data Scientist
# 602170         Data Engineer                            Data Engineer
#
#                                              job_location             job_via  \
# 468327                                             Norway        via LinkedIn
# ...

# %%
df.sample(10, random_state=42)  # Locks the sample() to display the sample values everytime

# %% [markdown]
# ## Copying Data
# **Using the copy()**

# %%
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
# Creates a new object with changes not reflected to the original
print(f'Original: {id(df_original)} Altered: {id(df_altered)}')
# Out:
# Original: 140150702211856 Altered: 140151554931856
