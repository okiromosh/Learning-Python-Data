# %%
import ast
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# %%
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = (
    df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
)

# %%
df_DA = df[df['job_title_short'] == 'Data Analyst'].copy()

# %%
df_DA['job_posted_month_no'] = df['job_posted_date'].dt.month
df_DA
# Out:
#        job_title_short  ... job_posted_month_no
# 1         Data Analyst  ...                   1
# 12        Data Analyst  ...                  12
# 18        Data Analyst  ...                  10
# 31        Data Analyst  ...                  10
# 34        Data Analyst  ...                   2
# ...                ...  ...                 ...
# 785703    Data Analyst  ...                   1
# 785705    Data Analyst  ...                   1
# 785715    Data Analyst  ...                   3
# 785717    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
#
# [196075 rows x 18 columns]

# %%
df_DA_explode = df_DA.explode('job_skills')
df_DA_explode
# Out:
#        job_title_short  ... job_posted_month_no
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# 1         Data Analyst  ...                   1
# ...                ...  ...                 ...
# 785717    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
# 785737    Data Analyst  ...                   3
#
# [672513 rows x 18 columns]

# %%
df_DA_pivot = df_DA_explode.pivot_table(index='job_posted_month_no', 
                          columns='job_skills', 
                          aggfunc='size',
                          fill_value=0)

# %%
df_DA_pivot.loc['Total'] = df_DA_pivot.sum()
df_DA_pivot
# Out:
# job_skills           airflow  airtable  alteryx  ...  xamarin  yarn  zoom
# job_posted_month_no                              ...
# 1                        197        17      551  ...        0     9    95
# 2                        169         2      448  ...        0     4    41
# 3                        181         4      442  ...        1     5    45
# 4                        155         4      413  ...        0     6    26
# 5                        128         8      310  ...        0     7    18
# 6                        164        14      393  ...        0    11    34
# 7                        207         4      366  ...        0     6    38
# 8                        197         3      413  ...        0    11    41
# 9                        118         4      317  ...        0     5    25
# 10                       173        11      350  ...        1     4    39
# 11                       169         7      293  ...        0     6    26
# 12                       144        10      274  ...        0     2    37
# Total                   2002        88     4570  ...        2    76   465
#
# [13 rows x 235 columns]

# %%
df_DA_pivot.loc['Total'].sort_values(ascending=False).index
df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
# Out:
# job_skills             sql  excel  python  ...  msaccess  ovh  suse
# job_posted_month_no                        ...
# 1                    11336   8170    6606  ...         0    0     0
# 2                     7947   5772    4751  ...         0    0     0
# 3                     7868   5675    4741  ...         0    0     1
# 4                     7553   5496    4557  ...         0    1     0
# 5                     6617   4773    4070  ...         1    0     0
# 6                     7584   5724    4707  ...         0    0     0
# 7                     7687   5513    4831  ...         0    0     0
# 8                     8823   6482    5576  ...         0    0     0
# 9                     6829   4886    4229  ...         0    0     0
# 10                    7474   5217    4693  ...         0    0     0
# 11                    6652   4776    4233  ...         0    0     0
# 12                    6058   4376    4196  ...         0    0     0
# Total                92428  66860   57190  ...         1    1     1
#
# [13 rows x 235 columns]

# %%
df_DA_pivot = df_DA_pivot[df_DA_pivot.loc['Total'].sort_values(ascending=False).index]
df_DA_pivot = df_DA_pivot.drop('Total')
df_DA_pivot
# Out:
# job_skills             sql  excel  python  ...  msaccess  ovh  suse
# job_posted_month_no                        ...
# 1                    11336   8170    6606  ...         0    0     0
# 2                     7947   5772    4751  ...         0    0     0
# 3                     7868   5675    4741  ...         0    0     1
# 4                     7553   5496    4557  ...         0    1     0
# 5                     6617   4773    4070  ...         1    0     0
# 6                     7584   5724    4707  ...         0    0     0
# 7                     7687   5513    4831  ...         0    0     0
# 8                     8823   6482    5576  ...         0    0     0
# 9                     6829   4886    4229  ...         0    0     0
# 10                    7474   5217    4693  ...         0    0     0
# 11                    6652   4776    4233  ...         0    0     0
# 12                    6058   4376    4196  ...         0    0     0
#
# [12 rows x 235 columns]

# %%
df_DA_pivot.iloc[:, :5].plot(kind='line')
plt.title('Top 5 Skills for Data Analysis per Month')
plt.xlabel('Month')
plt.ylabel('Count')
plt.show()
